# %%
import pandas as pd
import seaborn as sns

#Loading the data
df = pd.read_csv('C:/Users/patel/COSC301/Group22-Project/project-group22-project/data/raw/season-1819_csv.csv')
df
# Out:
#      Div        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    SP1  17/08/2018        Betis     Levante     0     3   A     0     1   A
# 1    SP1  17/08/2018       Girona  Valladolid     0     0   D     0     0   D
# 2    SP1  18/08/2018    Barcelona      Alaves     3     0   H     0     0   D
# 3    SP1  18/08/2018        Celta     Espanol     1     1   D     0     1   A
# 4    SP1  18/08/2018   Villarreal    Sociedad     1     2   A     1     1   D
# ..   ...         ...          ...         ...   ...   ...  ..   ...   ...  ..
# 375  SP1  18/05/2019      Levante  Ath Madrid     2     2   D     2     0   H
# 376  SP1  18/05/2019      Sevilla  Ath Bilbao     2     0   H     1     0   H
# 377  SP1  18/05/2019   Valladolid    Valencia     0     2   A     0     1   A
# 378  SP1  19/05/2019        Eibar   Barcelona     2     2   D     2     2   D
# 379  SP1  19/05/2019  Real Madrid       Betis     0     2   A     0     0   D
#
# ...

# %%
#Cleaning the data by removing unneccasary files (For us it was bookie info and bets made and such)

df2 = df.iloc[0:len(df), 1:22]
df2
# Out:
#            Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    17/08/2018        Betis     Levante     0     3   A     0     1   A  22
# 1    17/08/2018       Girona  Valladolid     0     0   D     0     0   D  13
# 2    18/08/2018    Barcelona      Alaves     3     0   H     0     0   D  25
# 3    18/08/2018        Celta     Espanol     1     1   D     0     1   A  12
# 4    18/08/2018   Villarreal    Sociedad     1     2   A     1     1   D  16
# ..          ...          ...         ...   ...   ...  ..   ...   ...  ..  ..
# 375  18/05/2019      Levante  Ath Madrid     2     2   D     2     0   H  17
# 376  18/05/2019      Sevilla  Ath Bilbao     2     0   H     1     0   H   9
# 377  18/05/2019   Valladolid    Valencia     0     2   A     0     1   A  19
# 378  19/05/2019        Eibar   Barcelona     2     2   D     2     2   D  15
# 379  19/05/2019  Real Madrid       Betis     0     2   A     0     0   D   9
#
# ...

# %%
#Process the data and organize it by showing home games and away games for top 4 teams in the league

#Barcelona
barHome= df2[df2['HomeTeam']== 'Barcelona']
barAway= df2[df2['AwayTeam']== 'Barcelona']
bar = pd.concat([barHome,barAway])
bar
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 2    18/08/2018    Barcelona       Alaves     3     0   H     0     0   D  25
# 26   02/09/2018    Barcelona       Huesca     8     2   H     3     2   H  31
# 45   23/09/2018    Barcelona       Girona     2     2   D     1     1   D  22
# 60   29/09/2018    Barcelona   Ath Bilbao     1     1   D     0     1   A  20
# 80   20/10/2018    Barcelona      Sevilla     4     2   H     2     0   H  23
# 97   28/10/2018    Barcelona  Real Madrid     5     1   H     2     0   H  13
# 116  11/11/2018    Barcelona        Betis     3     4   A     0     2   A  20
# 136  02/12/2018    Barcelona   Villarreal     2     0   H     1     0   H  16
# 164  22/12/2018    Barcelona        Celta     2     0   H     2     0   H   9
# 187  13/01/2019    Barcelona        Eibar     3     0   H     1     0   H   7
# 194  20/01/2019    Barcelona      Leganes     3     1   H     1     0   H  15
# ...

# %%
#Real Madrid
realMHome= df2[df2['HomeTeam']== 'Real Madrid']
realMAway= df2[df2['AwayTeam']== 'Real Madrid']
realM = pd.concat([realMHome,realMAway])
realM
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 6    19/08/2018  Real Madrid       Getafe     2     0   H     1     0   H  10
# 24   01/09/2018  Real Madrid      Leganes     4     1   H     1     1   D  17
# 43   22/09/2018  Real Madrid      Espanol     1     0   H     1     0   H  19
# 62   29/09/2018  Real Madrid   Ath Madrid     0     0   D     0     0   D  15
# 81   20/10/2018  Real Madrid      Levante     1     2   A     0     2   A  34
# 101  03/11/2018  Real Madrid   Valladolid     2     0   H     0     0   D  16
# 133  01/12/2018  Real Madrid     Valencia     2     0   H     1     0   H  13
# 153  15/12/2018  Real Madrid    Vallecano     1     0   H     1     0   H   9
# 177  06/01/2019  Real Madrid     Sociedad     0     2   A     0     1   A  28
# 193  19/01/2019  Real Madrid      Sevilla     2     0   H     0     0   D  23
# 217  03/02/2019  Real Madrid       Alaves     3     0   H     1     0   H  22
# ...

# %%
#Athletico Madrid

atlMHome= df2[df2['HomeTeam']== 'Ath Madrid']
atlMAway= df2[df2['AwayTeam']== 'Ath Madrid']
athlM = pd.concat([atlMHome,atlMAway])
athlM
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 13   25/08/2018   Ath Madrid    Vallecano     1     0   H     0     0   D   9
# 31   15/09/2018   Ath Madrid        Eibar     1     1   D     0     0   D  18
# 49   25/09/2018   Ath Madrid       Huesca     3     0   H     3     0   H  17
# 74   07/10/2018   Ath Madrid        Betis     1     0   H     0     0   D  13
# 92   27/10/2018   Ath Madrid     Sociedad     2     0   H     1     0   H  14
# 111  10/11/2018   Ath Madrid   Ath Bilbao     3     2   H     0     1   A   9
# 121  24/11/2018   Ath Madrid    Barcelona     1     1   D     0     0   D   3
# 141  08/12/2018   Ath Madrid       Alaves     3     0   H     1     0   H  12
# 163  22/12/2018   Ath Madrid      Espanol     1     0   H     0     0   D   8
# 186  13/01/2019   Ath Madrid      Levante     1     0   H     0     0   D  19
# 200  26/01/2019   Ath Madrid       Getafe     2     0   H     2     0   H  10
# ...

# %%
#Valencia

valHome= df2[df2['HomeTeam']== 'Valencia']
valAway= df2[df2['AwayTeam']== 'Valencia']
val = pd.concat([valHome,valAway])
val


##TASK 1 Finished here, task 2 done on Andy Deverakonda anaylisis file
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 9    20/08/2018     Valencia   Ath Madrid     1     1   D     0     1   A  13
# 33   15/09/2018     Valencia        Betis     0     0   D     0     0   D  12
# 55   26/09/2018     Valencia        Celta     1     1   D     1     0   H  14
# 77   07/10/2018     Valencia    Barcelona     1     1   D     1     1   D  10
# 82   20/10/2018     Valencia      Leganes     1     1   D     0     0   D  18
# 102  03/11/2018     Valencia       Girona     0     1   A     0     0   D  27
# 124  24/11/2018     Valencia    Vallecano     3     0   H     1     0   H  13
# 143  08/12/2018     Valencia      Sevilla     1     1   D     0     0   D  16
# 167  23/12/2018     Valencia       Huesca     2     1   H     1     0   H  19
# 183  12/01/2019     Valencia   Valladolid     1     1   D     0     0   D  17
# 203  26/01/2019     Valencia   Villarreal     3     0   H     1     0   H  18
# ...
