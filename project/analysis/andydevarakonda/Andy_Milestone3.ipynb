# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append('..')

# %%
from scripts import project_functions as pf
top_4 = pf.load_process("season-1819_csv.csv")
top_4
# Out:
#            Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 2    18/08/2018   Barcelona      Alaves     3     0   H     0     0   D  25
# 26   02/09/2018   Barcelona      Huesca     8     2   H     3     2   H  31
# 45   23/09/2018   Barcelona      Girona     2     2   D     1     1   D  22
# 60   29/09/2018   Barcelona  Ath Bilbao     1     1   D     0     1   A  20
# 80   20/10/2018   Barcelona     Sevilla     4     2   H     2     0   H  23
# ..          ...         ...         ...   ...   ...  ..   ...   ...  ..  ..
# 303  06/04/2019   Vallecano    Valencia     2     0   H     1     0   H  15
# 325  21/04/2019       Betis    Valencia     1     2   A     0     1   A  23
# 333  24/04/2019  Ath Madrid    Valencia     3     2   H     1     1   D  14
# 357  05/05/2019      Huesca    Valencia     2     6   A     0     5   A  24
# 377  18/05/2019  Valladolid    Valencia     0     2   A     0     1   A  19
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
top_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 2 to 377
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      152 non-null    object
#  1   HomeTeam  152 non-null    object
#  2   AwayTeam  152 non-null    object
#  3   FTHG      152 non-null    int64
#  4   FTAG      152 non-null    int64
#  5   FTR       152 non-null    object
#  6   HTHG      152 non-null    int64
#  7   HTAG      152 non-null    int64
#  8   HTR       152 non-null    object
#  9   HS        152 non-null    int64
#  10  AS        152 non-null    int64
#  11  HST       152 non-null    int64
#  12  AST       152 non-null    int64
#  13  HF        152 non-null    int64
#  14  AF        152 non-null    int64
#  15  HC        152 non-null    int64
#  16  AC        152 non-null    int64
#  17  HY        152 non-null    int64
#  18  AY        152 non-null    int64
#  19  HR        152 non-null    int64
# ...

# %%
top_4.describe().T
# Out:
#       count       mean       std  min   25%   50%    75%   max
# FTHG  152.0   1.519737  1.239367  0.0   1.0   1.0   2.00   8.0
# FTAG  152.0   1.144737  1.257601  0.0   0.0   1.0   2.00   6.0
# HTHG  152.0   0.585526  0.722799  0.0   0.0   0.0   1.00   3.0
# HTAG  152.0   0.552632  0.820188  0.0   0.0   0.0   1.00   5.0
# HS    152.0  14.322368  5.278473  3.0  11.0  13.0  17.25  34.0
# AS    152.0  10.605263  3.958657  3.0   8.0  10.0  14.00  21.0
# HST   152.0   5.177632  2.586521  1.0   3.0   5.0   7.00  15.0
# AST   152.0   3.756579  2.237539  0.0   2.0   3.0   5.00   9.0
# HF    152.0  13.151316  4.264065  1.0  10.0  12.0  16.00  25.0
# AF    152.0  12.769737  3.965865  3.0  10.0  13.0  15.00  27.0
# HC    152.0   5.671053  2.929133  0.0   4.0   5.0   8.00  15.0
# AC    152.0   4.144737  2.409715  0.0   2.0   4.0   6.00  12.0
# HY    152.0   2.348684  1.664828  0.0   1.0   2.0   3.00   7.0
# AY    152.0   2.625000  1.454896  0.0   2.0   3.0   3.00   7.0
# ...

# %%
barca_home = top_4[top_4["HomeTeam"] == "Barcelona"]
barca_home
# Out:
#            Date   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 2    18/08/2018  Barcelona       Alaves     3     0   H     0     0   D  25
# 26   02/09/2018  Barcelona       Huesca     8     2   H     3     2   H  31
# 45   23/09/2018  Barcelona       Girona     2     2   D     1     1   D  22
# 60   29/09/2018  Barcelona   Ath Bilbao     1     1   D     0     1   A  20
# 80   20/10/2018  Barcelona      Sevilla     4     2   H     2     0   H  23
# 97   28/10/2018  Barcelona  Real Madrid     5     1   H     2     0   H  13
# 116  11/11/2018  Barcelona        Betis     3     4   A     0     2   A  20
# 136  02/12/2018  Barcelona   Villarreal     2     0   H     1     0   H  16
# 164  22/12/2018  Barcelona        Celta     2     0   H     2     0   H   9
# 187  13/01/2019  Barcelona        Eibar     3     0   H     1     0   H   7
# 194  20/01/2019  Barcelona      Leganes     3     1   H     1     0   H  15
# ...

# %%
barca_away = top_4[top_4["AwayTeam"] == "Barcelona"]
barca_away
# Out:
#            Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 14   25/08/2018   Valladolid  Barcelona     0     1   A     0     0   D   7
# 32   15/09/2018     Sociedad  Barcelona     1     2   A     1     0   H   8
# 53   26/09/2018      Leganes  Barcelona     2     1   H     0     1   A  10
# 77   07/10/2018     Valencia  Barcelona     1     1   D     1     1   D  10
# 103  03/11/2018    Vallecano  Barcelona     2     3   A     1     1   D  11
# 121  24/11/2018   Ath Madrid  Barcelona     1     1   D     0     0   D   3
# 142  08/12/2018      Espanol  Barcelona     0     4   A     0     3   A  15
# 157  16/12/2018      Levante  Barcelona     0     5   A     0     2   A  20
# 176  06/01/2019       Getafe  Barcelona     1     2   A     1     2   A  10
# 206  27/01/2019       Girona  Barcelona     0     2   A     0     1   A  13
# 225  10/02/2019   Ath Bilbao  Barcelona     0     0   D     0     0   D  13
# ...

# %%
barcelona = pd.concat([barca_home, barca_away])
barcelona
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 2    18/08/2018    Barcelona       Alaves     3     0   H     0     0   D  25
# 26   02/09/2018    Barcelona       Huesca     8     2   H     3     2   H  31
# 45   23/09/2018    Barcelona       Girona     2     2   D     1     1   D  22
# 60   29/09/2018    Barcelona   Ath Bilbao     1     1   D     0     1   A  20
# 80   20/10/2018    Barcelona      Sevilla     4     2   H     2     0   H  23
# 97   28/10/2018    Barcelona  Real Madrid     5     1   H     2     0   H  13
# 116  11/11/2018    Barcelona        Betis     3     4   A     0     2   A  20
# 136  02/12/2018    Barcelona   Villarreal     2     0   H     1     0   H  16
# 164  22/12/2018    Barcelona        Celta     2     0   H     2     0   H   9
# 187  13/01/2019    Barcelona        Eibar     3     0   H     1     0   H   7
# 194  20/01/2019    Barcelona      Leganes     3     1   H     1     0   H  15
# ...

# %%
goal_diffh_barca = barca_home["FTHG"]-barca_home["FTAG"]
goal_diffa_barca = barca_away["FTAG"]-barca_away["FTHG"]

goal_diffh_rma = top_4[top_4["HomeTeam"] == "Real Madrid"]["FTHG"]-top_4[top_4["HomeTeam"] == "Real Madrid"]["FTAG"]
goal_diffa_rma = top_4[top_4["AwayTeam"] == "Real Madrid"]["FTAG"]-top_4[top_4["AwayTeam"] == "Real Madrid"]["FTHG"]

goal_diffh_atl =top_4[top_4["HomeTeam"] == "Ath Madrid"]["FTHG"]-top_4[top_4["HomeTeam"] == "Ath Madrid"]["FTAG"]
goal_diffa_atl = top_4[top_4["AwayTeam"] == "Ath Madrid"]["FTAG"]-top_4[top_4["AwayTeam"] == "Ath Madrid"]["FTHG"]

goal_diffh_val = top_4[top_4["HomeTeam"] == "Valencia"]["FTHG"]-top_4[top_4["HomeTeam"] == "Valencia"]["FTAG"]
goal_diffa_val = top_4[top_4["AwayTeam"] == "Valencia"]["FTAG"]-top_4[top_4["AwayTeam"] == "Valencia"]["FTHG"]



goal_diff_barca = pd.concat([goal_diffh_barca,goal_diffa_barca])
goal_diff_barca.reset_index(drop=True, inplace=True)

goal_diff_rma = pd.concat([goal_diffh_rma,goal_diffa_rma])
goal_diff_rma.reset_index(drop=True, inplace=True)

goal_diff_atl = pd.concat([goal_diffh_atl,goal_diffa_atl])
goal_diff_atl.reset_index(drop=True, inplace=True)

goal_diff_val = pd.concat([goal_diffh_val,goal_diffa_val])
goal_diff_val.reset_index(drop=True, inplace=True)



goal_diff = pd.DataFrame();


goal_diff.insert(0, "Barca Goal Diff", goal_diff_barca)
goal_diff.insert(1,"Real Madrid Goal Diff", goal_diff_rma)
goal_diff.insert(2,"Ath Madrid Goal Diff", goal_diff_atl)
goal_diff.insert(3," Valencia Goal Diff", goal_diff_val)
goal_diff


homeshots_barca = barca_home["HST"]
awayshots_barca = barca_away["AST"]

homeshots_rma= top_4[top_4["HomeTeam"] == "Real Madrid"]["HST"]
awayshots_rma = top_4[top_4["AwayTeam"] == "Real Madrid"]["AST"]

homeshots_atl =top_4[top_4["HomeTeam"] == "Ath Madrid"]["HST"]
awayshots_atl = top_4[top_4["AwayTeam"] == "Ath Madrid"]["AST"]

homeshots_val = top_4[top_4["HomeTeam"] == "Valencia"]["HST"]
awayshots_val = top_4[top_4["AwayTeam"] == "Valencia"]["AST"]

homeshots_barca_total = pd.concat([homeshots_barca,awayshots_barca])
homeshots_barca_total.reset_index(drop=True, inplace=True)

homeshots_rma_total = pd.concat([homeshots_rma,awayshots_rma])
homeshots_rma_total.reset_index(drop=True, inplace=True)

homeshots_atl_total = pd.concat([homeshots_atl,awayshots_atl])
homeshots_atl_total.reset_index(drop=True, inplace=True)

homeshots_val_total = pd.concat([homeshots_val,awayshots_val])
homeshots_val_total.reset_index(drop=True, inplace=True)


goal_diff.insert(4, "Barca Shots on target", homeshots_barca_total)
goal_diff.insert(5,"Real Madrid Shots on target", homeshots_rma_total)
goal_diff.insert(6,"Ath Madrid Shots on target", homeshots_atl_total)
goal_diff.insert(7," Valencia Shots on target", homeshots_val_total)
goal_diff
# Out:
#     Barca Goal Diff  Real Madrid Goal Diff  Ath Madrid Goal Diff  \
# 0                 3                     -1                     0
# 1                 6                      2                    -2
# 2                 0                      3                     1
# 3                 0                      1                     0
# 4                 2                      0                     3
# 5                 4                     -1                     1
# 6                -1                      2                     2
# 7                 2                      2                     1
# 8                 2                      1                     0
# 9                 3                     -2                     3
# 10                2                      2                     1
# 11                0                      3                     1
# 12                1                     -1                     2
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(data=goal_diff,ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # The above graph showcases the barplots between the goal difference and the shots on target for the top 4 teams

# %%
new_gdiff = goal_diff.iloc[:,0:4]

f, ax = plt.subplots(figsize=(10, 12))
a = sns.heatmap(new_gdiff, annot=True, fmt="d", linewidths=.5, ax=ax)
#Heatmap for goal difference and shots on target

# %%
new_gdiff2 = goal_diff.iloc[:,4:8]
f, ax2 = plt.subplots(figsize=(10, 12))
sns.heatmap(new_gdiff2, annot=True, fmt="d", linewidths=.5, ax=ax2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## The above two graph showcases the heatmaps between the goal difference and the shots on target for the top 4 teams

# %%
fig, ax = plt.subplots(figsize=(20, 16))
sns.boxplot(data = goal_diff,ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # The above graph showcases the boxplot between the goal difference and the shots on target for the top 4 teams
