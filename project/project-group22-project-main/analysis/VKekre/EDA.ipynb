# %%
import sys
import pandas as pd
sys.path.append('..')
import seaborn as sns
from scripts import project_functions as pf

# %%
#Dataframe:

# %%
df = pf.load_process("season-1819_csv.csv")
df
# Out:
#            Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 2    18/08/2018   Barcelona      Alaves     3     0   H     0     0   D  25
# 26   02/09/2018   Barcelona      Huesca     8     2   H     3     2   H  31
# 45   23/09/2018   Barcelona      Girona     2     2   D     1     1   D  22
# 60   29/09/2018   Barcelona  Ath Bilbao     1     1   D     0     1   A  20
# 80   20/10/2018   Barcelona     Sevilla     4     2   H     2     0   H  23
# ..          ...         ...         ...   ...   ...  ..   ...   ...  ..  ..
# 303  06/04/2019   Vallecano    Valencia     2     0   H     1     0   H  15
# 325  21/04/2019       Betis    Valencia     1     2   A     0     1   A  23
# 333  24/04/2019  Ath Madrid    Valencia     3     2   H     1     1   D  14
# 357  05/05/2019      Huesca    Valencia     2     6   A     0     5   A  24
# 377  18/05/2019  Valladolid    Valencia     0     2   A     0     1   A  19
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 2 to 377
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      152 non-null    object
#  1   HomeTeam  152 non-null    object
#  2   AwayTeam  152 non-null    object
#  3   FTHG      152 non-null    int64
#  4   FTAG      152 non-null    int64
#  5   FTR       152 non-null    object
#  6   HTHG      152 non-null    int64
#  7   HTAG      152 non-null    int64
#  8   HTR       152 non-null    object
#  9   HS        152 non-null    int64
#  10  AS        152 non-null    int64
#  11  HST       152 non-null    int64
#  12  AST       152 non-null    int64
#  13  HF        152 non-null    int64
#  14  AF        152 non-null    int64
#  15  HC        152 non-null    int64
#  16  AC        152 non-null    int64
#  17  HY        152 non-null    int64
#  18  AY        152 non-null    int64
#  19  HR        152 non-null    int64
# ...

# %%
df.describe().T
# Out:
#       count       mean       std  min   25%   50%    75%   max
# FTHG  152.0   1.519737  1.239367  0.0   1.0   1.0   2.00   8.0
# FTAG  152.0   1.144737  1.257601  0.0   0.0   1.0   2.00   6.0
# HTHG  152.0   0.585526  0.722799  0.0   0.0   0.0   1.00   3.0
# HTAG  152.0   0.552632  0.820188  0.0   0.0   0.0   1.00   5.0
# HS    152.0  14.322368  5.278473  3.0  11.0  13.0  17.25  34.0
# AS    152.0  10.605263  3.958657  3.0   8.0  10.0  14.00  21.0
# HST   152.0   5.177632  2.586521  1.0   3.0   5.0   7.00  15.0
# AST   152.0   3.756579  2.237539  0.0   2.0   3.0   5.00   9.0
# HF    152.0  13.151316  4.264065  1.0  10.0  12.0  16.00  25.0
# AF    152.0  12.769737  3.965865  3.0  10.0  13.0  15.00  27.0
# HC    152.0   5.671053  2.929133  0.0   4.0   5.0   8.00  15.0
# AC    152.0   4.144737  2.409715  0.0   2.0   4.0   6.00  12.0
# HY    152.0   2.348684  1.664828  0.0   1.0   2.0   3.00   7.0
# AY    152.0   2.625000  1.454896  0.0   2.0   3.0   3.00   7.0
# ...

# %%
sns.pairplot(df)

# %%
Real_Madrid_h = df[df["HomeTeam"] == "Real Madrid"]
Real_Madrid_h
# Out:
#            Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
#
# 177  06/01/2019  Real Madrid     Sociedad     0     2   A     0     1   A  28
# 193  19/01/2019  Real Madrid      Sevilla     2     0   H     0     0   D  23
# ...

# %%
diff_HS_RM = Real_Madrid_h["HS"]-Real_Madrid_h["AS"]
diff_AS_RM = Real_Madrid_away["AS"]-Real_Madrid_away["HS"]

# %%
diff_HS_barca = df[df["HomeTeam"] == "Barcelona"]["HS"]-df[df["HomeTeam"] == "Barcelona"]["AS"]
diff_AS_barca = df[df["AwayTeam"] == "Barcelona"]["AS"]-df[df["AwayTeam"] == "Barcelona"]["HS"]

# %%
diff_HS_Ath_Mardid = df[df["HomeTeam"] == "Ath Madrid"]["HS"]-df[df["HomeTeam"] == "Ath Madrid"]["AS"]
diff_AS_Ath_Madrid = df[df["AwayTeam"] == "Ath Madrid"]["AS"]-df[df["AwayTeam"] == "Ath Madrid"]["HS"]

# %%
diff_HS_Valencia = df[df["HomeTeam"] == "Valencia"]["HS"]-df[df["HomeTeam"] == "Valencia"]["AS"]
diff_AS_Valencia = df[df["AwayTeam"] == "Valencia"]["AS"]-df[df["AwayTeam"] == "Valencia"]["HS"]

# %%
diff_RM = pd.concat([diff_HS_RM,diff_AS_RM])
diff_RM.reset_index(drop=True, inplace=True)
diff_barca = pd.concat([diff_HS_barca,diff_AS_barca])
diff_barca.reset_index(drop=True, inplace=True)
diff_Ath_Madrid = pd.concat([diff_HS_Ath_Mardid,diff_AS_Ath_Madrid])
diff_Ath_Madrid.reset_index(drop=True, inplace=True)
diff_valencia = pd.concat([diff_HS_Valencia,diff_AS_Valencia])
diff_valencia.reset_index(drop=True, inplace=True)

# %%
df1 = pd.DataFrame();
df1.insert(0, "Difference Real Madrid",diff_RM )
df1.insert(1,"Difference Barca",diff_barca)
df1.insert(2,"Difference Ath Madrid ",diff_Ath_Madrid)
df1.insert(3," Difference Valencia ",diff_valencia )
df1
# Out:
#     Difference Real Madrid  Difference Barca  Difference Ath Madrid   \
# 0                        7                22                      -5
# 1                        6                24                       0
# 2                        9                15                      -4
# 3                        9                12                       6
# 4                        7                 4                       9
# 5                       28                -2                       8
# 6                        4                 5                       7
# 7                        6                 4                       3
# 8                       -2                -2                      -5
# 9                       16                -8                      -1
# 10                      19                10                     -10
# 11                      14                 6                      12
# 12                       5                10                       4
# ...

# %%
sns.displot(data = df1,kde=True)

# %%
# The distribuiton plot above demonstrates difference betwwen the shots taken at home and away for the top 4 teams.

# %%
sns.countplot(data=df1)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# The countplot above demonstrates difference betwwen the shots taken at home and away for the top 4 teams.

# %%
sns.scatterplot(data = df1)
# Out:
# <AxesSubplot:>

# %%
# the scatterplot above demonstrates difference betwwen the shots taken at home and away for the top 4 teams.

# %%
sns.boxplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
#the boxplot above demonstrates difference betwwen the shots taken at home and away for the top 4 teams.
